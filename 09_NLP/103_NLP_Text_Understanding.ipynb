# %% [markdown]
# # Natural Language Understanding
#
# In this section we go through topics related to text understanding. We cover such topics like:
#
# - Similarity measures
# - Word Vectors
# - Vector Space Model
# - Type of vectorizers
# - Build a vectorizer with Tensorflow.

# %% [markdown]
# ## Similarity measures
#
# Word does have different meanings. This makes the comparison and analysis a bit more complex.

# %%
from textblob import Word

w = Word("developer")

for synset, definition in zip(w.get_synsets(), w.define()):
    print(synset, definition)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from textblob import Word
#       3 w = Word("developer")
#       5 for synset, definition in zip(w.get_synsets(), w.define()):
#
# ModuleNotFoundError: No module named 'textblob'

# %% [markdown]
# ## Similarity measures
#
# There are plenty of methods to measure the similarity of strings. Two most popular Python libraries examples for such measure are shown. We compare two strings: trains and training. The SequenceMatcher class allow us to use the Gestalt pattern matching algorithm:

# %%
from difflib import SequenceMatcher
a = "training"
b = "trains"
print(len(a))
print(len(b))
ratio = SequenceMatcher(None, a, b).ratio()
print(ratio)
# Out:
# 8
# 6
# 0.7142857142857143

# %% [markdown]
# The distance is a normalized value between 0 and 1, where 1 means identical.
#
# A different approach is shown below. We use the Jellyfish library. There are a few methods that we can use here. One of it is the Levenshtein distance. Below the distance and normalize distance values are calculated.

# %%
import jellyfish
distance = jellyfish.levenshtein_distance(a,b)
print(distance)

normalized_distance = distance/max(len(a),len(b))
print(1.0-normalized_distance)
# Out:
# 3
# 0.625

# %% [markdown]
# Some words can be more similar to each other than other. We can build a similarity matrix to check it where 1 mean equal and 0 totally different.

# %%
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()

tokens = nlp(u'king queen horse cat desk lamp')

for first_token in tokens:
    for second_token in tokens:
        print(first_token.text, second_token.text, first_token.similarity(second_token))
# Out:
# king king 1.0
# king queen 0.6128482222557068
# king horse 0.5876098871231079
# king cat 0.6193754076957703
# king desk 0.5271511077880859
# king lamp 0.25223037600517273
# queen king 0.6128482222557068
# queen queen 1.0
# queen horse 0.6164734363555908
# queen cat 0.6143932342529297
# queen desk 0.6345311403274536
# queen lamp 0.3886454999446869
# horse king 0.5876098871231079
# horse queen 0.6164734363555908
# horse horse 1.0
# horse cat 0.6475561261177063
# horse desk 0.6181738376617432
# horse lamp 0.37150055170059204
# cat king 0.6193754076957703
# cat queen 0.6143932342529297
# cat horse 0.6475561261177063
# cat cat 1.0
# cat desk 0.7207602262496948
# cat lamp 0.4289367198944092
# desk king 0.5271511077880859
# desk queen 0.6345311403274536
# desk horse 0.6181738376617432
# desk cat 0.7207602262496948
# desk desk 1.0
# desk lamp 0.4279959797859192
# lamp king 0.25223037600517273
# lamp queen 0.3886454999446869
# lamp horse 0.37150055170059204
# lamp cat 0.4289367198944092
# lamp desk 0.4279959797859192
# lamp lamp 1.0
# /tmp/nix-shell.Ox0Yif/ipykernel_260516/18702037.py:9: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Token.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   print(first_token.text, second_token.text, first_token.similarity(second_token))

# %% [markdown]
# We can also compare sentences:

# %%
doc1 = nlp(u"Warsaw is the largest city in Poland.")
doc2 = nlp(u"Crossaint is baked in France.")
doc3 = nlp(u"An emu is a large bird.")

for doc in [doc1, doc2, doc3]:
    for other_doc in [doc1, doc2, doc3]:
        print(doc.similarity(other_doc))
# Out:
# 1.0
# 0.6390468803250852
# 0.6041416025106453
# 0.6390468803250852
# 1.0
# 0.5464452551815584
# 0.6041416025106453
# 0.5464452551815584
# 1.0
# /tmp/nix-shell.Ox0Yif/ipykernel_260516/2306317000.py:7: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   print(doc.similarity(other_doc))

# %% [markdown]
# The similarity matrix looks like following:
#
# |       | doc1 | doc2 | doc3 |
# |-------|------|------|------|
# | **doc1** | 1.0  | 0.72 | 0.65 |
# | **doc 2** | 0.72 | 1.0  | 0.40 |
# | **doc 3** | 0.65 | 0.40 | 1.0  |

# %% [markdown]
# ## Word Vectors
#
# SpaCy does have already a set of words that are vectorized.
#
# Let's take a look at the vectors that are available in spaCy using the previous example:

# %%
nlp = en_core_web_sm.load()

tokens = nlp(u'king queen horse cat desk lamp')

for token in tokens:
    print(str(token)+" "+str(token.vector))
# Out:
# king [-1.1133616  -1.0715381   0.17498347  0.2983135  -1.1198013   0.06686684
#   0.83400404  0.8415991  -0.81147885 -0.04442363  2.0902855   0.61689997
#  -1.6941863  -0.18409964 -0.57307726 -0.08472103 -1.5606233  -0.4961265
#  -0.4470026  -0.53579384  0.23178513  1.6318842   1.3830286   0.55126584
#   0.325065    0.3905236   0.66175556  1.4945935   0.01249412 -0.31671014
#  -0.8269541  -0.94043803 -0.15464754  0.12148196 -0.736446   -0.11215541
#   0.49824756 -0.5074818   0.1346393   0.01301625 -1.4823344   1.1512142
#  -0.28982484  0.4669568  -0.2697815  -0.47252363 -0.10474992  0.5826209
#   0.14604366  0.09867011 -0.5415132  -0.63924223  0.98515934 -0.7425058
#  -0.8650961  -0.45056728  1.1102725  -0.31695974  0.66481125 -0.32102245
#  -0.9101965  -0.43204626 -0.0340566  -1.2508934  -0.93322    -0.49311382
#  -0.18716311  1.8433582   0.56230295 -0.705404    1.1738945  -0.29050007
#   0.4054772  -0.8470016   0.29123953  0.13989909 -0.24977589  0.203008
#   0.43926707 -0.86123663  0.06630252 -0.41542214 -0.9165709  -0.4205838
#   0.37674224  0.24384844  1.0312278   0.35045853 -1.6494653   2.7033298
#  -0.5622667  -0.6861725   1.4618864   1.1946261  -0.16982934 -0.43460906]
# queen [-0.37585926 -0.22783187 -0.17754933  0.2240848  -0.3814221  -0.65432465
#  -0.4382235   1.1086161   0.48133957  0.20535329  1.0081049   0.5709239
#  -0.9446218  -1.6891531  -0.5299079   1.0792842  -0.75228333 -0.8943316
#  -0.27015358 -0.16810352 -1.8750736   1.1595246  -0.09531897  0.5280493
#   0.440508   -0.30263448  0.29241654  0.5490167  -0.51858395  0.5295664
#  -0.65046    -1.0339658  -0.22098252  0.27502424 -0.30927715  0.8942239
#  -0.03018877  0.24795121 -1.0318785   0.0222508  -1.1670947  -0.3451606
#  -0.82337874  0.5719677  -0.596501   -0.36289746 -0.04797193  0.17415354
#  -0.590108    0.67465687 -1.0130321  -0.4466073   1.1311777  -0.45838222
#  -0.594229   -0.35278317  0.606648   -0.2434318   0.6605072   0.7514581
#  -0.5847207  -0.11173925  0.32779425 -1.8098587  -1.2682455  -0.6497684
#   0.2045668   2.061624    0.69062954  0.14792575  1.0086356   0.6275617
#   0.2613819  -0.6976751   0.48818132  0.18296102 -1.5275371  -0.12796128
#  -0.02149658  0.40780252  0.821013   -0.00990514 -0.01816332  0.25383034
#  -1.106614   -0.11158313  0.8665708   0.4009422  -1.5239727   0.9643687
#   0.21211135  0.20422758  0.938298    1.17167     0.1282743   0.06375252]
# horse [ 0.26981306 -0.8503853   0.6629999  -0.10520118 -0.29207295 -0.5769103
#   0.66527855  1.0636955   0.22613806  0.9370972   0.6412041   0.179972
#  -0.7695819  -0.45101774 -0.20414843 -0.1483135  -0.5883882  -0.8291353
#  -1.1980428  -1.0853612  -0.15512767  0.3927855  -0.37840837  0.18030772
#   0.8550324   0.26064897  0.24214602  0.14442351  0.03359106  0.12366219
#   0.20659605 -0.50300306 -0.5165316   0.39684922 -0.6552292  -0.04400459
#   0.11165501  1.1496563  -1.2189038  -0.8911115  -0.49729562 -0.1760984
#   0.1871207   0.634773   -0.05311945 -0.5772834  -0.07041246  0.07284477
#  -0.9191493   0.32997948 -0.04333061 -0.09063585  1.0819905  -0.65896285
#  -0.6560519  -0.10788918  0.49232063  0.03111375  0.61287415 -0.41501814
#  -0.72472715  1.0359267   0.20366931 -1.2729156  -1.1582413  -0.30190542
#   0.30132553  0.16677359  0.7431678   0.02514619  1.4824349   1.7555993
#   0.30208614 -1.7992423   0.20330754  0.12125643 -0.3637653  -0.59568024
#   0.7708225  -0.3780566   0.83677226 -0.88907737 -0.90906817 -0.39991897
#  -0.17149061  0.06391293  0.48030153 -0.1110822  -1.2787809   1.7248296
#   0.00991088 -0.38250944  1.1908922   0.8664949  -0.26275206  0.10944104]
# cat [-0.30014268 -1.3117056   0.59683174 -0.24878252 -0.4581236  -0.48287845
#  -0.05125737  2.0879052  -0.01478633  0.5056718   0.58081377  0.32325208
#  -0.8567404  -1.0935905  -0.33039632  1.0177279  -0.3671874  -0.40231597
#  -0.6748332  -0.45253205 -0.0742895   0.682039   -1.0706903   0.22255391
#   1.1950324   0.6030866  -0.03437937  1.3283513   0.31412172  1.0026238
#  -0.76836044 -0.28534037 -0.08941276  0.5249873  -1.0465474  -0.9321175
#   1.0063453  -0.7027597  -0.9219246  -0.50486106 -0.66210663  0.0084151
#  -0.3185499   2.3155015  -1.2937608  -0.7886419  -0.22986983  0.24185243
#   0.2383259  -0.12327701 -0.55816805 -0.1521203   0.99397784 -0.5581816
#  -1.6414493   0.12058266  0.6085406   0.30127507  0.72939825 -0.37101373
#  -0.940137   -0.381212    0.47422478  0.16558072 -1.1576055  -1.042134
#   0.27811164  1.8732684   0.25097513 -1.0220966   1.7427192   0.75980157
#   1.2569057  -1.6417758   0.44534904 -0.09325427 -1.3338896  -0.14732033
#   0.47633487 -1.3674623   0.16238052 -0.25987217  0.07576938 -0.5633061
#   0.29995954 -0.7394194  -0.10188986  0.23709093 -1.2469805   1.316896
#   0.39837942  0.1959005   1.5106112   0.55947447 -0.60240734  0.67016846]
# desk [ 0.08208929 -2.0213814   0.27953622  0.06674813 -0.44277894 -0.39398712
#   0.17494947  2.3849056   0.38074255 -0.06191856  0.8787922   0.62040555
#  -0.4506194  -1.3012726  -0.91024756  1.1268709  -0.27908385 -0.12406209
#  -1.1983137  -0.132594    0.2438578   0.6256578  -0.5065039   0.397774
#  -0.10258591  0.86529166 -0.33482504  0.62255883  0.30352855  0.8572657
#  -0.16401039 -0.74238276 -0.39248714  0.6192728  -0.7552378  -0.8690915
#   0.98781997  0.15155718 -1.633551   -1.031538   -0.77041936  0.11127335
#  -0.4509024   1.6354183   0.34787473  0.10355197  0.14720717 -0.38862076
#  -0.98386276  0.62570083 -0.83337677 -0.73401237  0.5212335  -0.3283463
#  -0.16277188  0.37778646  1.4243274  -0.5645405  -0.06810279 -0.35371184
#  -0.24773566 -0.6381383   0.9051792  -1.0602801  -1.3864344  -0.5691355
#   0.45838773  1.4234293   0.02428102  0.6400039   1.9541963   0.17022482
#   0.9989789  -1.024518    0.19018248 -0.0504719  -0.6969857  -0.07907443
#  -0.7357576  -0.32085854  0.23241195  0.09527469 -1.1186062  -0.18213463
#  -0.3847196  -0.99250716  0.59343493 -0.6945155  -1.3455453   1.0468664
#   0.8964311   0.9953976   0.5658997   0.5552025   0.16306272  0.07836289]
# lamp [-1.5008998  -0.51154506 -0.9993163   0.23946327  1.078236   -0.6669775
#   0.0631938   1.8099817   0.60793376  0.5721179   0.30884588 -0.0620156
#  -0.6847507   0.0965887  -0.88095295  1.005423   -1.1312885  -0.4028119
#   1.3418521   0.64977956 -0.9489874  -0.08342552 -1.6829946  -0.3398819
#  -0.16075009 -0.11345989  0.23802072  0.03285712 -0.6798907   0.3735319
#  -0.19887014  0.7539155   0.6445545   1.5864882  -0.24731255 -0.81828445
#   0.6998315   1.5426506  -0.61425817 -0.91558367 -0.54106414 -0.23684454
#  -0.24727714  0.67735654 -0.6413317   0.24767342  0.00532359  0.28107744
#  -0.12855864  0.54835767  0.59556836  1.3833789   0.8849957  -0.07932323
#  -0.04548022 -0.06340575  1.8029683  -0.34584534  1.2568771   0.1130724
#  -0.77544945 -0.69441825  0.2776826  -0.71112746 -0.5741423   0.25421742
#  -0.6490494  -0.09836182 -0.8116264   0.54740566  0.614703    0.47254336
#   1.1088375  -0.66763747  0.39200068  0.09340304 -0.9394855  -0.35871673
#  -1.0176833  -1.0709445  -0.09994537 -0.11503908 -0.6550231  -0.6874732
#  -0.87093085 -0.16206029 -0.84512126 -0.8173717  -0.9270265   0.8353298
#  -0.76354814 -0.1697478   1.7046349   0.48494008  0.85970324  0.87817705]

# %% [markdown]
# It looks that the vectors are quite long. It's easy to check the exact size of a vector:

# %%
len(tokens[1].vector)
# Out:
# 96

# %% [markdown]
# You can play around and check the vector values for some other sentences. Let's take a look at sentence vectors of one of our previous examples:

# %%
len(doc1.vector)
# Out:
# 96

# %% [markdown]
# A nice example of word vectorization done by some researchers at Warsaw University: [Word2Vec](https://lamyiowce.github.io/word2viz/).

# %% [markdown]
# ## Negative sampling
#
# It is a simpler implementation of word2vec. It is faster as it takes only a few terms in each iteration for training insted of the whole dataset as in previous example. This is why it's called negative sampling.
#
# First of all, we define helper methods that are used later.

# %%
def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def sigmoid(batch, stochastic=False):
    return  1.0 / (1.0 + np.exp(-batch))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

# %% [markdown]
# We need to load the data again.

# %%
import nltk
import numpy as np
import pandas as pd
from collections import namedtuple

nltk.download('all')

from nltk.book import *

texts()
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/piotrek/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /home/piotrek/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# Three variables are important for the training: ``train_dict``, ``train_tokens`` and ``train_set``. The first one contain all unique words used in the corpus. The second is a list of indices of words in the dictionary that correspond to each word used in the raw text.

# %%
#raw_set = nltk.corpus.treebank_raw.raw()[0:50000].replace('.START',' ').replace("\n","").replace("."," ").replace(","," ")
#tokens = [token for token in nltk.word_tokenize(raw_set) if token.isalpha()]
tokens = text6.tokens
train_dict = pd.Series(tokens).unique().tolist()
train_tokens = np.array([train_dict.index(token) for token in tokens])

# %% [markdown]
# The last variable consist of a list of two numbers. The current word index and the word index that is before the word and after the word. Depending on the window size we use also other words that are in the neighbourhood. In this example the window size is set to 2. It means we take two words before and two words after the given word and build the relation in the training data set.

# %%
train_set = []
for i in range(2,len(tokens)-2):
    train_set.append([train_dict.index(tokens[i]), train_dict.index(tokens[i-1])])
    train_set.append([train_dict.index(tokens[i]), train_dict.index(tokens[i-2])])
    train_set.append([train_dict.index(tokens[i]), train_dict.index(tokens[i+1])])
    train_set.append([train_dict.index(tokens[i]), train_dict.index(tokens[i+2])])

train_set = np.random.permutation(np.array(train_set))

# %% [markdown]
# The next step is to set the training configuration. We set the the negative samples size to 10 and the vector size to 100. Learning rate and rate decay are set to 0.1 and 0.995. The training loops are set to 8000000. Logs are displayed each 10000 epoches.

# %%
Config = namedtuple("Config", ["dict_size", "vect_size", "neg_samples", "updates", "learning_rate",
                               "learning_rate_decay", "decay_period", "log_period"])
conf = Config(
    dict_size=len(train_dict),
    vect_size=100,
    neg_samples=10,
    updates=8000000,
    learning_rate=0.1,
    learning_rate_decay=0.995,
    decay_period=10000,
    log_period=10000)

# %% [markdown]
# We loop over ``updates`` and get the word and context from the train set. We calculate the negative context and calculate the word, context and negative sample vectors. The negative context is chosen randomly. In the next step we calcualte the cost and corresponding to it gradients.

# %%
def neg_sample(conf, train_set, train_tokens):
    Vp = randn(conf.dict_size, conf.vect_size)
    Vo = randn(conf.dict_size, conf.vect_size)

    J = 0.0
    learning_rate = conf.learning_rate
    for i in range(conf.updates):
        idx = i % len(train_set)

        word = train_set[idx, 0]
        context = train_set[idx, 1]

        neg_context = np.random.randint(0, len(train_tokens), conf.neg_samples)
        neg_context = train_tokens[neg_context]

        word_vect = Vp[word, :]  # word vector
        context_vect = Vo[context, :];  # context wector
        negative_vects = Vo[neg_context, :]  # sampled negative vectors

        # Cost and gradient calculation starts here
        score_pos = word_vect @ context_vect.T
        score_neg = word_vect @ negative_vects.T

        J -= np.log(sigmoid(score_pos)) + np.sum(np.log(sigmoid(-score_neg)))
        if (i + 1) % conf.log_period == 0:
            print('Update {0}\tcost: {1:>2.2f}'.format(i + 1, J / conf.log_period))
            final_cost = J / conf.log_period
            J = 0.0

        pos_g = 1.0 - sigmoid(score_pos)
        neg_g = sigmoid(score_neg)

        word_grad = -pos_g * context_vect + np.sum(as_matrix(neg_g) * negative_vects, axis=0)
        context_grad = -pos_g * word_vect
        neg_context_grad = as_matrix(neg_g) * as_matrix(word_vect).T

        Vp[word, :] -= learning_rate * word_grad
        Vo[context, :] -= learning_rate * context_grad
        Vo[neg_context, :] -= learning_rate * neg_context_grad

        if i % conf.decay_period == 0:
            learning_rate = learning_rate * conf.learning_rate_decay

    return Vp, Vo, final_cost

# %% [markdown]
# Next do the training:

# %%
Vp, Vo, J = neg_sample(conf, train_set, train_tokens)
# Out:
# Update 10000	cost: 18.59
# Update 20000	cost: 10.84
# Update 30000	cost: 8.49
# Update 40000	cost: 7.39
# Update 50000	cost: 6.57
# Update 60000	cost: 6.09
# Update 70000	cost: 5.59
# Update 80000	cost: 4.86
# Update 90000	cost: 4.63
# Update 100000	cost: 4.45
# Update 110000	cost: 4.30
# Update 120000	cost: 4.22
# Update 130000	cost: 4.17
# Update 140000	cost: 4.01
# Update 150000	cost: 3.79
# Update 160000	cost: 3.74
# Update 170000	cost: 3.69
# Update 180000	cost: 3.63
# Update 190000	cost: 3.61
# Update 200000	cost: 3.58
# Update 210000	cost: 3.50
# Update 220000	cost: 3.39
# Update 230000	cost: 3.40
# Update 240000	cost: 3.33
# Update 250000	cost: 3.31
# Update 260000	cost: 3.31
# Update 270000	cost: 3.27
# Update 280000	cost: 3.18
# Update 290000	cost: 3.17
# Update 300000	cost: 3.13
# Update 310000	cost: 3.09
# Update 320000	cost: 3.09
# Update 330000	cost: 3.12
# Update 340000	cost: 3.05
# Update 350000	cost: 3.00
# Update 360000	cost: 2.99
# Update 370000	cost: 2.96
# Update 380000	cost: 2.96
# Update 390000	cost: 2.94
# Update 400000	cost: 2.94
# Update 410000	cost: 2.91
# Update 420000	cost: 2.84
# Update 430000	cost: 2.86
# Update 440000	cost: 2.85
# Update 450000	cost: 2.84
# Update 460000	cost: 2.84
# Update 470000	cost: 2.82
# Update 480000	cost: 2.80
# Update 490000	cost: 2.77
# Update 500000	cost: 2.75
# Update 510000	cost: 2.77
# Update 520000	cost: 2.74
# Update 530000	cost: 2.74
# Update 540000	cost: 2.74
# Update 550000	cost: 2.72
# Update 560000	cost: 2.69
# Update 570000	cost: 2.65
# Update 580000	cost: 2.67
# Update 590000	cost: 2.68
# Update 600000	cost: 2.68
# Update 610000	cost: 2.65
# Update 620000	cost: 2.63
# Update 630000	cost: 2.61
# Update 640000	cost: 2.63
# Update 650000	cost: 2.61
# Update 660000	cost: 2.61
# Update 670000	cost: 2.61
# Update 680000	cost: 2.57
# Update 690000	cost: 2.56
# Update 700000	cost: 2.56
# Update 710000	cost: 2.58
# Update 720000	cost: 2.53
# Update 730000	cost: 2.57
# Update 740000	cost: 2.55
# Update 750000	cost: 2.53
# Update 760000	cost: 2.54
# Update 770000	cost: 2.50
# Update 780000	cost: 2.53
# Update 790000	cost: 2.50
# Update 800000	cost: 2.53
# Update 810000	cost: 2.49
# Update 820000	cost: 2.49
# Update 830000	cost: 2.47
# Update 840000	cost: 2.46
# Update 850000	cost: 2.48
# Update 860000	cost: 2.47
# Update 870000	cost: 2.49
# Update 880000	cost: 2.46
# Update 890000	cost: 2.44
# Update 900000	cost: 2.44
# Update 910000	cost: 2.42
# Update 920000	cost: 2.46
# Update 930000	cost: 2.44
# Update 940000	cost: 2.43
# Update 950000	cost: 2.41
# Update 960000	cost: 2.41
# Update 970000	cost: 2.40
# Update 980000	cost: 2.40
# Update 990000	cost: 2.41
# Update 1000000	cost: 2.43
# Update 1010000	cost: 2.41
# Update 1020000	cost: 2.38
# Update 1030000	cost: 2.37
# Update 1040000	cost: 2.37
# Update 1050000	cost: 2.38
# Update 1060000	cost: 2.39
# Update 1070000	cost: 2.39
# Update 1080000	cost: 2.36
# Update 1090000	cost: 2.35
# Update 1100000	cost: 2.36
# Update 1110000	cost: 2.36
# Update 1120000	cost: 2.37
# Update 1130000	cost: 2.35
# Update 1140000	cost: 2.37
# Update 1150000	cost: 2.36
# Update 1160000	cost: 2.34
# Update 1170000	cost: 2.31
# Update 1180000	cost: 2.35
# Update 1190000	cost: 2.35
# Update 1200000	cost: 2.32
# Update 1210000	cost: 2.35
# Update 1220000	cost: 2.33
# Update 1230000	cost: 2.31
# Update 1240000	cost: 2.29
# Update 1250000	cost: 2.32
# Update 1260000	cost: 2.32
# Update 1270000	cost: 2.35
# Update 1280000	cost: 2.32
# Update 1290000	cost: 2.27
# Update 1300000	cost: 2.29
# Update 1310000	cost: 2.27
# Update 1320000	cost: 2.30
# Update 1330000	cost: 2.29
# Update 1340000	cost: 2.33
# Update 1350000	cost: 2.31
# Update 1360000	cost: 2.28
# Update 1370000	cost: 2.24
# Update 1380000	cost: 2.27
# Update 1390000	cost: 2.28
# Update 1400000	cost: 2.27
# Update 1410000	cost: 2.29
# Update 1420000	cost: 2.26
# Update 1430000	cost: 2.26
# Update 1440000	cost: 2.25
# Update 1450000	cost: 2.27
# Update 1460000	cost: 2.26
# Update 1470000	cost: 2.25
# Update 1480000	cost: 2.27
# Update 1490000	cost: 2.25
# Update 1500000	cost: 2.24
# Update 1510000	cost: 2.24
# Update 1520000	cost: 2.26
# Update 1530000	cost: 2.25
# Update 1540000	cost: 2.24
# Update 1550000	cost: 2.24
# Update 1560000	cost: 2.23
# Update 1570000	cost: 2.24
# Update 1580000	cost: 2.21
# Update 1590000	cost: 2.23
# Update 1600000	cost: 2.25
# Update 1610000	cost: 2.24
# Update 1620000	cost: 2.23
# Update 1630000	cost: 2.21
# Update 1640000	cost: 2.21
# Update 1650000	cost: 2.19
# Update 1660000	cost: 2.22
# Update 1670000	cost: 2.22
# Update 1680000	cost: 2.24
# Update 1690000	cost: 2.22
# Update 1700000	cost: 2.21
# Update 1710000	cost: 2.20
# Update 1720000	cost: 2.20
# Update 1730000	cost: 2.21
# Update 1740000	cost: 2.20
# Update 1750000	cost: 2.24
# Update 1760000	cost: 2.19
# Update 1770000	cost: 2.20
# Update 1780000	cost: 2.18
# Update 1790000	cost: 2.18
# Update 1800000	cost: 2.21
# Update 1810000	cost: 2.19
# Update 1820000	cost: 2.21
# Update 1830000	cost: 2.20
# Update 1840000	cost: 2.17
# Update 1850000	cost: 2.17
# Update 1860000	cost: 2.19
# Update 1870000	cost: 2.20
# Update 1880000	cost: 2.20
# Update 1890000	cost: 2.19
# Update 1900000	cost: 2.17
# Update 1910000	cost: 2.17
# Update 1920000	cost: 2.15
# Update 1930000	cost: 2.17
# Update 1940000	cost: 2.19
# Update 1950000	cost: 2.20
# Update 1960000	cost: 2.19
# Update 1970000	cost: 2.17
# Update 1980000	cost: 2.16
# Update 1990000	cost: 2.14
# Update 2000000	cost: 2.17
# Update 2010000	cost: 2.16
# Update 2020000	cost: 2.18
# Update 2030000	cost: 2.17
# Update 2040000	cost: 2.16
# Update 2050000	cost: 2.16
# Update 2060000	cost: 2.16
# Update 2070000	cost: 2.16
# Update 2080000	cost: 2.16
# Update 2090000	cost: 2.16
# Update 2100000	cost: 2.17
# Update 2110000	cost: 2.13
# Update 2120000	cost: 2.12
# Update 2130000	cost: 2.15
# Update 2140000	cost: 2.17
# Update 2150000	cost: 2.15
# Update 2160000	cost: 2.16
# Update 2170000	cost: 2.15
# Update 2180000	cost: 2.14
# Update 2190000	cost: 2.12
# Update 2200000	cost: 2.14
# Update 2210000	cost: 2.15
# Update 2220000	cost: 2.12
# Update 2230000	cost: 2.16
# Update 2240000	cost: 2.13
# Update 2250000	cost: 2.14
# Update 2260000	cost: 2.12
# Update 2270000	cost: 2.12
# Update 2280000	cost: 2.14
# Update 2290000	cost: 2.15
# Update 2300000	cost: 2.15
# Update 2310000	cost: 2.12
# Update 2320000	cost: 2.11
# Update 2330000	cost: 2.12
# Update 2340000	cost: 2.14
# Update 2350000	cost: 2.12
# Update 2360000	cost: 2.14
# Update 2370000	cost: 2.11
# Update 2380000	cost: 2.12
# Update 2390000	cost: 2.09
# Update 2400000	cost: 2.12
# Update 2410000	cost: 2.11
# Update 2420000	cost: 2.11
# Update 2430000	cost: 2.12
# Update 2440000	cost: 2.12
# Update 2450000	cost: 2.11
# Update 2460000	cost: 2.11
# Update 2470000	cost: 2.12
# Update 2480000	cost: 2.13
# Update 2490000	cost: 2.11
# Update 2500000	cost: 2.10
# Update 2510000	cost: 2.11
# Update 2520000	cost: 2.12
# Update 2530000	cost: 2.09
# Update 2540000	cost: 2.11
# Update 2550000	cost: 2.10
# Update 2560000	cost: 2.11
# Update 2570000	cost: 2.12
# Update 2580000	cost: 2.10
# Update 2590000	cost: 2.08
# Update 2600000	cost: 2.08
# Update 2610000	cost: 2.10
# Update 2620000	cost: 2.10
# Update 2630000	cost: 2.11
# Update 2640000	cost: 2.12
# Update 2650000	cost: 2.10
# Update 2660000	cost: 2.07
# Update 2670000	cost: 2.08
# Update 2680000	cost: 2.10
# Update 2690000	cost: 2.10
# Update 2700000	cost: 2.11
# Update 2710000	cost: 2.09
# Update 2720000	cost: 2.09
# Update 2730000	cost: 2.07
# Update 2740000	cost: 2.09
# Update 2750000	cost: 2.09
# Update 2760000	cost: 2.10
# Update 2770000	cost: 2.10
# Update 2780000	cost: 2.09
# Update 2790000	cost: 2.07
# Update 2800000	cost: 2.07
# Update 2810000	cost: 2.08
# Update 2820000	cost: 2.09
# Update 2830000	cost: 2.08
# Update 2840000	cost: 2.09
# Update 2850000	cost: 2.08
# Update 2860000	cost: 2.07
# Update 2870000	cost: 2.06
# Update 2880000	cost: 2.09
# Update 2890000	cost: 2.08
# Update 2900000	cost: 2.08
# Update 2910000	cost: 2.09
# Update 2920000	cost: 2.07
# Update 2930000	cost: 2.08
# Update 2940000	cost: 2.05
# Update 2950000	cost: 2.08
# Update 2960000	cost: 2.06
# Update 2970000	cost: 2.09
# Update 2980000	cost: 2.06
# Update 2990000	cost: 2.05
# Update 3000000	cost: 2.05
# Update 3010000	cost: 2.07
# Update 3020000	cost: 2.08
# Update 3030000	cost: 2.08
# Update 3040000	cost: 2.07
# Update 3050000	cost: 2.06
# Update 3060000	cost: 2.05
# Update 3070000	cost: 2.05
# Update 3080000	cost: 2.07
# Update 3090000	cost: 2.06
# Update 3100000	cost: 2.05
# Update 3110000	cost: 2.08
# Update 3120000	cost: 2.07
# Update 3130000	cost: 2.06
# Update 3140000	cost: 2.05
# Update 3150000	cost: 2.05
# Update 3160000	cost: 2.08
# Update 3170000	cost: 2.06
# Update 3180000	cost: 2.06
# Update 3190000	cost: 2.04
# Update 3200000	cost: 2.05
# Update 3210000	cost: 2.05
# Update 3220000	cost: 2.05
# Update 3230000	cost: 2.07
# Update 3240000	cost: 2.06
# Update 3250000	cost: 2.05
# Update 3260000	cost: 2.05
# Update 3270000	cost: 2.03
# Update 3280000	cost: 2.04
# Update 3290000	cost: 2.06
# Update 3300000	cost: 2.03
# Update 3310000	cost: 2.08
# Update 3320000	cost: 2.04
# Update 3330000	cost: 2.05
# Update 3340000	cost: 2.01
# Update 3350000	cost: 2.05
# Update 3360000	cost: 2.05
# Update 3370000	cost: 2.04
# Update 3380000	cost: 2.07
# Update 3390000	cost: 2.05
# Update 3400000	cost: 2.02
# Update 3410000	cost: 2.02
# Update 3420000	cost: 2.04
# Update 3430000	cost: 2.05
# Update 3440000	cost: 2.05
# Update 3450000	cost: 2.05
# Update 3460000	cost: 2.03
# Update 3470000	cost: 2.03
# Update 3480000	cost: 2.01
# Update 3490000	cost: 2.04
# Update 3500000	cost: 2.03
# Update 3510000	cost: 2.05
# Update 3520000	cost: 2.04
# Update 3530000	cost: 2.03
# Update 3540000	cost: 2.02
# Update 3550000	cost: 2.02
# Update 3560000	cost: 2.04
# Update 3570000	cost: 2.03
# Update 3580000	cost: 2.03
# Update 3590000	cost: 2.04
# Update 3600000	cost: 2.03
# Update 3610000	cost: 2.02
# Update 3620000	cost: 2.03
# Update 3630000	cost: 2.04
# Update 3640000	cost: 2.02
# Update 3650000	cost: 2.05
# Update 3660000	cost: 2.02
# Update 3670000	cost: 2.03
# Update 3680000	cost: 2.01
# Update 3690000	cost: 2.02
# Update 3700000	cost: 2.05
# Update 3710000	cost: 2.02
# Update 3720000	cost: 2.03
# Update 3730000	cost: 2.03
# Update 3740000	cost: 2.01
# Update 3750000	cost: 2.01
# Update 3760000	cost: 2.02
# Update 3770000	cost: 2.02
# Update 3780000	cost: 2.02
# Update 3790000	cost: 2.02
# Update 3800000	cost: 2.01
# Update 3810000	cost: 2.03
# Update 3820000	cost: 2.00
# Update 3830000	cost: 2.02
# Update 3840000	cost: 2.02
# Update 3850000	cost: 2.03
# Update 3860000	cost: 2.02
# Update 3870000	cost: 2.01
# Update 3880000	cost: 2.00
# Update 3890000	cost: 2.00
# Update 3900000	cost: 2.02
# Update 3910000	cost: 2.02
# Update 3920000	cost: 2.03
# Update 3930000	cost: 2.02
# Update 3940000	cost: 2.01
# Update 3950000	cost: 2.00
# Update 3960000	cost: 2.01
# Update 3970000	cost: 2.02
# Update 3980000	cost: 2.00
# Update 3990000	cost: 2.03
# Update 4000000	cost: 2.02
# Update 4010000	cost: 1.99
# Update 4020000	cost: 1.99
# Update 4030000	cost: 2.01
# Update 4040000	cost: 2.01
# Update 4050000	cost: 2.00
# Update 4060000	cost: 2.03
# Update 4070000	cost: 2.02
# Update 4080000	cost: 1.99
# Update 4090000	cost: 2.00
# Update 4100000	cost: 1.99
# Update 4110000	cost: 2.01
# Update 4120000	cost: 2.01
# Update 4130000	cost: 2.02
# Update 4140000	cost: 2.00
# Update 4150000	cost: 2.01
# Update 4160000	cost: 1.99
# Update 4170000	cost: 2.01
# Update 4180000	cost: 2.01
# Update 4190000	cost: 2.00
# Update 4200000	cost: 2.01
# Update 4210000	cost: 2.00
# Update 4220000	cost: 1.99
# Update 4230000	cost: 1.99
# Update 4240000	cost: 2.00
# Update 4250000	cost: 1.99
# Update 4260000	cost: 2.02
# Update 4270000	cost: 2.01
# Update 4280000	cost: 2.00
# Update 4290000	cost: 1.98
# Update 4300000	cost: 2.01
# Update 4310000	cost: 2.00
# Update 4320000	cost: 2.00
# Update 4330000	cost: 2.01
# Update 4340000	cost: 1.99
# Update 4350000	cost: 1.97
# Update 4360000	cost: 1.98
# Update 4370000	cost: 2.00
# Update 4380000	cost: 2.00
# Update 4390000	cost: 2.00
# Update 4400000	cost: 1.99
# Update 4410000	cost: 1.99
# Update 4420000	cost: 2.00
# Update 4430000	cost: 1.98
# Update 4440000	cost: 1.99
# Update 4450000	cost: 2.01
# Update 4460000	cost: 1.99
# Update 4470000	cost: 2.00
# Update 4480000	cost: 1.98
# Update 4490000	cost: 1.98
# Update 4500000	cost: 1.98
# Update 4510000	cost: 1.99
# Update 4520000	cost: 2.00
# Update 4530000	cost: 1.98
# Update 4540000	cost: 1.98
# Update 4550000	cost: 2.00
# Update 4560000	cost: 1.98
# Update 4570000	cost: 1.99
# Update 4580000	cost: 1.99
# Update 4590000	cost: 1.98
# Update 4600000	cost: 1.99
# Update 4610000	cost: 1.98
# Update 4620000	cost: 1.99
# Update 4630000	cost: 1.98
# Update 4640000	cost: 1.99
# Update 4650000	cost: 2.00
# Update 4660000	cost: 1.98
# Update 4670000	cost: 2.00
# Update 4680000	cost: 1.98
# Update 4690000	cost: 1.97
# Update 4700000	cost: 1.97
# Update 4710000	cost: 2.00
# Update 4720000	cost: 1.99
# Update 4730000	cost: 1.99
# Update 4740000	cost: 2.00
# Update 4750000	cost: 1.98
# Update 4760000	cost: 1.98
# Update 4770000	cost: 1.97
# Update 4780000	cost: 1.98
# Update 4790000	cost: 1.99
# Update 4800000	cost: 1.99
# Update 4810000	cost: 1.98
# Update 4820000	cost: 1.98
# Update 4830000	cost: 1.97
# Update 4840000	cost: 1.96
# Update 4850000	cost: 1.98
# Update 4860000	cost: 1.97
# Update 4870000	cost: 2.00
# Update 4880000	cost: 1.98
# Update 4890000	cost: 1.97
# Update 4900000	cost: 1.96
# Update 4910000	cost: 1.99
# Update 4920000	cost: 1.98
# Update 4930000	cost: 1.98
# Update 4940000	cost: 1.99
# Update 4950000	cost: 1.98
# Update 4960000	cost: 1.96
# Update 4970000	cost: 1.96
# Update 4980000	cost: 1.98
# Update 4990000	cost: 1.97
# Update 5000000	cost: 1.97
# Update 5010000	cost: 1.99
# Update 5020000	cost: 1.98
# Update 5030000	cost: 1.96
# Update 5040000	cost: 1.96
# Update 5050000	cost: 1.97
# Update 5060000	cost: 1.97
# Update 5070000	cost: 1.98
# Update 5080000	cost: 1.99
# Update 5090000	cost: 1.97
# Update 5100000	cost: 1.97
# Update 5110000	cost: 1.94
# Update 5120000	cost: 1.99
# Update 5130000	cost: 1.97
# Update 5140000	cost: 1.98
# Update 5150000	cost: 1.97
# Update 5160000	cost: 1.96
# Update 5170000	cost: 1.95
# Update 5180000	cost: 1.97
# Update 5190000	cost: 1.98
# Update 5200000	cost: 1.96
# Update 5210000	cost: 1.99
# Update 5220000	cost: 1.96
# Update 5230000	cost: 1.95
# Update 5240000	cost: 1.96
# Update 5250000	cost: 1.97
# Update 5260000	cost: 1.98
# Update 5270000	cost: 1.97
# Update 5280000	cost: 1.97
# Update 5290000	cost: 1.96
# Update 5300000	cost: 1.96
# Update 5310000	cost: 1.96
# Update 5320000	cost: 1.97
# Update 5330000	cost: 1.97
# Update 5340000	cost: 1.97
# Update 5350000	cost: 1.97
# Update 5360000	cost: 1.97
# Update 5370000	cost: 1.96
# Update 5380000	cost: 1.94
# Update 5390000	cost: 1.97
# Update 5400000	cost: 1.95
# Update 5410000	cost: 1.97
# Update 5420000	cost: 1.97
# Update 5430000	cost: 1.94
# Update 5440000	cost: 1.95
# Update 5450000	cost: 1.95
# Update 5460000	cost: 1.96
# Update 5470000	cost: 1.96
# Update 5480000	cost: 1.96
# Update 5490000	cost: 1.96
# Update 5500000	cost: 1.96
# Update 5510000	cost: 1.94
# Update 5520000	cost: 1.97
# Update 5530000	cost: 1.97
# Update 5540000	cost: 1.96
# Update 5550000	cost: 1.97
# Update 5560000	cost: 1.95
# Update 5570000	cost: 1.95
# Update 5580000	cost: 1.95
# Update 5590000	cost: 1.97
# Update 5600000	cost: 1.96
# Update 5610000	cost: 1.94
# Update 5620000	cost: 1.97
# Update 5630000	cost: 1.97
# Update 5640000	cost: 1.94
# Update 5650000	cost: 1.95
# Update 5660000	cost: 1.96
# Update 5670000	cost: 1.95
# Update 5680000	cost: 1.96
# Update 5690000	cost: 1.96
# Update 5700000	cost: 1.95
# Update 5710000	cost: 1.95
# Update 5720000	cost: 1.94
# Update 5730000	cost: 1.96
# Update 5740000	cost: 1.95
# Update 5750000	cost: 1.99
# Update 5760000	cost: 1.96
# Update 5770000	cost: 1.95
# Update 5780000	cost: 1.94
# Update 5790000	cost: 1.94
# Update 5800000	cost: 1.97
# Update 5810000	cost: 1.95
# Update 5820000	cost: 1.97
# Update 5830000	cost: 1.96
# Update 5840000	cost: 1.95
# Update 5850000	cost: 1.94
# Update 5860000	cost: 1.96
# Update 5870000	cost: 1.95
# Update 5880000	cost: 1.95
# Update 5890000	cost: 1.97
# Update 5900000	cost: 1.96
# Update 5910000	cost: 1.95
# Update 5920000	cost: 1.93
# Update 5930000	cost: 1.96
# Update 5940000	cost: 1.96
# Update 5950000	cost: 1.95
# Update 5960000	cost: 1.96
# Update 5970000	cost: 1.95
# Update 5980000	cost: 1.94
# Update 5990000	cost: 1.95
# Update 6000000	cost: 1.95
# Update 6010000	cost: 1.95
# Update 6020000	cost: 1.96
# Update 6030000	cost: 1.96
# Update 6040000	cost: 1.93
# Update 6050000	cost: 1.94
# Update 6060000	cost: 1.93
# Update 6070000	cost: 1.96
# Update 6080000	cost: 1.95
# Update 6090000	cost: 1.95
# Update 6100000	cost: 1.94
# Update 6110000	cost: 1.95
# Update 6120000	cost: 1.95
# Update 6130000	cost: 1.94
# Update 6140000	cost: 1.96
# Update 6150000	cost: 1.93
# Update 6160000	cost: 1.95
# Update 6170000	cost: 1.94
# Update 6180000	cost: 1.93
# Update 6190000	cost: 1.93
# Update 6200000	cost: 1.95
# Update 6210000	cost: 1.95
# Update 6220000	cost: 1.94
# Update 6230000	cost: 1.96
# Update 6240000	cost: 1.95
# Update 6250000	cost: 1.92
# Update 6260000	cost: 1.94
# Update 6270000	cost: 1.95
# Update 6280000	cost: 1.95
# Update 6290000	cost: 1.94
# Update 6300000	cost: 1.95
# Update 6310000	cost: 1.94
# Update 6320000	cost: 1.93
# Update 6330000	cost: 1.92
# Update 6340000	cost: 1.95
# Update 6350000	cost: 1.94
# Update 6360000	cost: 1.95
# Update 6370000	cost: 1.96
# Update 6380000	cost: 1.95
# Update 6390000	cost: 1.93
# Update 6400000	cost: 1.92
# Update 6410000	cost: 1.94
# Update 6420000	cost: 1.95
# Update 6430000	cost: 1.95
# Update 6440000	cost: 1.95
# Update 6450000	cost: 1.94
# Update 6460000	cost: 1.92
# Update 6470000	cost: 1.94
# Update 6480000	cost: 1.95
# Update 6490000	cost: 1.95
# Update 6500000	cost: 1.94
# Update 6510000	cost: 1.93
# Update 6520000	cost: 1.92
# Update 6530000	cost: 1.93
# Update 6540000	cost: 1.94
# Update 6550000	cost: 1.95
# Update 6560000	cost: 1.94
# Update 6570000	cost: 1.94
# Update 6580000	cost: 1.95
# Update 6590000	cost: 1.93
# Update 6600000	cost: 1.93
# Update 6610000	cost: 1.94
# Update 6620000	cost: 1.94
# Update 6630000	cost: 1.94
# Update 6640000	cost: 1.95
# Update 6650000	cost: 1.94
# Update 6660000	cost: 1.93
# Update 6670000	cost: 1.93
# Update 6680000	cost: 1.94
# Update 6690000	cost: 1.94
# Update 6700000	cost: 1.94
# Update 6710000	cost: 1.95
# Update 6720000	cost: 1.93
# Update 6730000	cost: 1.91
# Update 6740000	cost: 1.92
# Update 6750000	cost: 1.95
# Update 6760000	cost: 1.93
# Update 6770000	cost: 1.94
# Update 6780000	cost: 1.94
# Update 6790000	cost: 1.93
# Update 6800000	cost: 1.91
# Update 6810000	cost: 1.94
# Update 6820000	cost: 1.93
# Update 6830000	cost: 1.92
# Update 6840000	cost: 1.94
# Update 6850000	cost: 1.93
# Update 6860000	cost: 1.92
# Update 6870000	cost: 1.92
# Update 6880000	cost: 1.94
# Update 6890000	cost: 1.94
# Update 6900000	cost: 1.94
# Update 6910000	cost: 1.94
# Update 6920000	cost: 1.93
# Update 6930000	cost: 1.92
# Update 6940000	cost: 1.92
# Update 6950000	cost: 1.93
# Update 6960000	cost: 1.93
# Update 6970000	cost: 1.93
# Update 6980000	cost: 1.94
# Update 6990000	cost: 1.92
# Update 7000000	cost: 1.92
# Update 7010000	cost: 1.91
# Update 7020000	cost: 1.94
# Update 7030000	cost: 1.93
# Update 7040000	cost: 1.93
# Update 7050000	cost: 1.93
# Update 7060000	cost: 1.93
# Update 7070000	cost: 1.91
# Update 7080000	cost: 1.92
# Update 7090000	cost: 1.94
# Update 7100000	cost: 1.93
# Update 7110000	cost: 1.95
# Update 7120000	cost: 1.93
# Update 7130000	cost: 1.92
# Update 7140000	cost: 1.92
# Update 7150000	cost: 1.92
# Update 7160000	cost: 1.93
# Update 7170000	cost: 1.93
# Update 7180000	cost: 1.93
# Update 7190000	cost: 1.93
# Update 7200000	cost: 1.91
# Update 7210000	cost: 1.92
# Update 7220000	cost: 1.94
# Update 7230000	cost: 1.94
# Update 7240000	cost: 1.93
# Update 7250000	cost: 1.93
# Update 7260000	cost: 1.94
# Update 7270000	cost: 1.92
# Update 7280000	cost: 1.91
# Update 7290000	cost: 1.92
# Update 7300000	cost: 1.93
# Update 7310000	cost: 1.93
# Update 7320000	cost: 1.92
# Update 7330000	cost: 1.93
# Update 7340000	cost: 1.90
# Update 7350000	cost: 1.92
# Update 7360000	cost: 1.93
# Update 7370000	cost: 1.92
# Update 7380000	cost: 1.93
# Update 7390000	cost: 1.92
# Update 7400000	cost: 1.92
# Update 7410000	cost: 1.92
# Update 7420000	cost: 1.92
# Update 7430000	cost: 1.94
# Update 7440000	cost: 1.92
# Update 7450000	cost: 1.94
# Update 7460000	cost: 1.92
# Update 7470000	cost: 1.91
# Update 7480000	cost: 1.91
# Update 7490000	cost: 1.92
# Update 7500000	cost: 1.93
# Update 7510000	cost: 1.91
# Update 7520000	cost: 1.93
# Update 7530000	cost: 1.93
# Update 7540000	cost: 1.91
# Update 7550000	cost: 1.92
# Update 7560000	cost: 1.93
# Update 7570000	cost: 1.92
# Update 7580000	cost: 1.93
# Update 7590000	cost: 1.93
# Update 7600000	cost: 1.93
# Update 7610000	cost: 1.92
# Update 7620000	cost: 1.91
# Update 7630000	cost: 1.93
# Update 7640000	cost: 1.92
# Update 7650000	cost: 1.94
# Update 7660000	cost: 1.92
# Update 7670000	cost: 1.92
# Update 7680000	cost: 1.90
# Update 7690000	cost: 1.92
# Update 7700000	cost: 1.93
# Update 7710000	cost: 1.92
# Update 7720000	cost: 1.94
# Update 7730000	cost: 1.92
# Update 7740000	cost: 1.91
# Update 7750000	cost: 1.91
# Update 7760000	cost: 1.93
# Update 7770000	cost: 1.92
# Update 7780000	cost: 1.92
# Update 7790000	cost: 1.94
# Update 7800000	cost: 1.93
# Update 7810000	cost: 1.90
# Update 7820000	cost: 1.91
# Update 7830000	cost: 1.92
# Update 7840000	cost: 1.92
# Update 7850000	cost: 1.93
# Update 7860000	cost: 1.94
# Update 7870000	cost: 1.92
# Update 7880000	cost: 1.91
# Update 7890000	cost: 1.91
# Update 7900000	cost: 1.93
# Update 7910000	cost: 1.92
# Update 7920000	cost: 1.92
# Update 7930000	cost: 1.92
# Update 7940000	cost: 1.91
# Update 7950000	cost: 1.92
# Update 7960000	cost: 1.91
# Update 7970000	cost: 1.93
# Update 7980000	cost: 1.92
# Update 7990000	cost: 1.92
# Update 8000000	cost: 1.92

# %% [markdown]
# The ``similar_words`` can be used to find related words of the ``word``.

# %%
def lookup_word_idx(word, word_dict):
    try:
        return np.argwhere(np.array(word_dict) == word)[0][0]
    except:
        raise Exception("No such word in dict: {}".format(word))

def similar_words(embeddings, word, word_dict, hits):
    word_idx = lookup_word_idx(word, word_dict)
    similarity_scores = embeddings @ embeddings[word_idx]
    similar_word_idxs = np.argsort(-similarity_scores)    
    return [word_dict[i] for i in similar_word_idxs[:hits]]

# %%
print('\n\nTraining cost: {0:>2.2f}\n\n'.format(J))

sample_words = ['knight', 'holy', 'grail']

Vp_norm = Vp / as_matrix(np.linalg.norm(Vp , axis=1))
for w in sample_words:
    similar = similar_words(Vp_norm, w, train_dict, 5)
    print('Words similar to {}: {}'.format(w, ", ".join(similar)))
# Out:
# Training cost: 1.92
#
#
# Words similar to knight: knight, mumble, stone, VILLAGER, squeak
# Words similar to holy: holy, pussy, j, clank, Bedwere
# Words similar to grail: grail, Grenade, rabbit, dona, expensive

# %% [markdown]
# #### References
#
# [1] Jeffrey Pennington, Richard Socher, and Christopher D. Manning. 2014. GloVe: Global Vectors for Word Representation.
